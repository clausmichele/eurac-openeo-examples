# %% [markdown]
# <img src="https://avatars.githubusercontent.com/u/74911464?s=200&v=4"
#      alt="OpenEO Platform logo"
#      style="float: left; margin-right: 10px;" />
# # OpenEO Platform - Client Side Processing

# %% [markdown]
# In this interactive notebook we will show some usage eaxample of the Client Side Processing functionality added recently to the openEO Python client.

# %% [markdown]
# ## Requirements

# %% [markdown]
# To use this functionality, you need `3.9<=Python<3.11`.
#
# You can install it using:
#     `pip install openeo[localprocessing]`
#
# <div class="alert alert-block alert-warning">
# This functionality is still under development and the installation procedure might change.
# Please refer to official documentation page for the most up to date instructions:
#
# <a href="url">https://open-eo.github.io/openeo-python-client/cookbook/localprocessing.html</a>

# %% [markdown]
# ## Sample Datasets

# %% [markdown]
# Clone the repository containing sample datasets provided by openEO Platform:

# %%
import os
if not os.path.exists('./openeo-localprocessing-data'):
    # !git clone https://github.com/Open-EO/openeo-localprocessing-data.git

# %% [markdown]
# Initialize the local collections and inspect them:

# %%
from openeo.local import LocalConnection
local_conn = LocalConnection(['./openeo-localprocessing-data'])
local_conn.list_collections()
# Out:
# Did not load machine learning processes due to missing dependencies: Install them like this: `pip install openeo-processes-dask[implementations, ml]`
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# Warning 1: TIFFReadDirectory:Sum of Photometric type-related color channels and ExtraSamples doesn't match SamplesPerPixel. Defining non-color channels as ExtraSamples.
# [{'stac_version': '1.0.0-rc.2',
#   'type': 'Collection',
#   'id': 'openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc',
#   'title': '',
#   'description': '',
#   'license': '',
#   'providers': [{'name': 'openEO platform - Geotrellis backend: 0.9.5a1',
#     'roles': ['producer'],
#     'url': ''}],
#   'links': '',
#   'extent': {'spatial': {'bbox': [[11.279049925697631,
#       46.46209368370743,
#       11.403371964733001,
#       46.52290723269475]]},
#    'temporal': {'interval': [['2022-06-02T00:00:00.000000000',
#       '2022-06-30T00:00:00.000000000']]}},
#   'cube:dimensions': {'t': {'type': 'temporal',
#     'extent': ['2022-06-02T00:00:00.000000000',
#      '2022-06-30T00:00:00.000000000']},
#    'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [674995.0, 684335.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N", GEOGCS["WGS 84", DATUM["World Geodetic System 1984", SPHEROID["WGS 84", 6378137.0, 298.257223563, AUTHORITY["EPSG","7030"]], AUTHORITY["EPSG","6326"]], PRIMEM["Greenwich", 0.0, AUTHORITY["EPSG","8901"]], UNIT["degree", 0.017453292519943295], AXIS["Geodetic longitude", EAST], AXIS["Geodetic latitude", NORTH], AUTHORITY["EPSG","4326"]], PROJECTION["Transverse_Mercator", AUTHORITY["EPSG","9807"]], PARAMETER["central_meridian", 9.0], PARAMETER["latitude_of_origin", 0.0], PARAMETER["scale_factor", 0.9996], PARAMETER["false_easting", 500000.0], PARAMETER["false_northing", 0.0], UNIT["m", 1.0], AXIS["Easting", EAST], AXIS["Northing", NORTH], AUTHORITY["EPSG","32632"]]'},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [5147915.0, 5154955.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N", GEOGCS["WGS 84", DATUM["World Geodetic System 1984", SPHEROID["WGS 84", 6378137.0, 298.257223563, AUTHORITY["EPSG","7030"]], AUTHORITY["EPSG","6326"]], PRIMEM["Greenwich", 0.0, AUTHORITY["EPSG","8901"]], UNIT["degree", 0.017453292519943295], AXIS["Geodetic longitude", EAST], AXIS["Geodetic latitude", NORTH], AUTHORITY["EPSG","4326"]], PROJECTION["Transverse_Mercator", AUTHORITY["EPSG","9807"]], PARAMETER["central_meridian", 9.0], PARAMETER["latitude_of_origin", 0.0], PARAMETER["scale_factor", 0.9996], PARAMETER["false_easting", 500000.0], PARAMETER["false_northing", 0.0], UNIT["m", 1.0], AXIS["Easting", EAST], AXIS["Northing", NORTH], AUTHORITY["EPSG","32632"]]'},
#    'bands': {'type': 'bands', 'values': ['B04', 'B03', 'B02', 'B08', 'SCL']}}},
#  {'stac_version': '1.0.0-rc.2',
#   'type': 'Collection',
#   'id': 'openeo-localprocessing-data/sample_netcdf/S1_GRD_sample.nc',
#   'title': '',
#   'description': '',
#   'license': '',
#   'providers': [{'name': 'openEO platform - Geotrellis backend: 0.11.0a1',
#     'roles': ['producer'],
#     'url': ''}],
#   'links': '',
#   'extent': {'spatial': {'bbox': [[11.189208394640481,
#       46.40417961647009,
#       11.524144741350124,
#       46.58555387746835]]},
#    'temporal': {'interval': [['2022-06-21T00:00:00.000000000',
#       '2022-06-21T00:00:00.000000000']]}},
#   'cube:dimensions': {'t': {'type': 'temporal',
#     'extent': ['2022-06-21T00:00:00.000000000',
#      '2022-06-21T00:00:00.000000000']},
#    'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [668275.0, 693375.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N", GEOGCS["WGS 84", DATUM["World Geodetic System 1984", SPHEROID["WGS 84", 6378137.0, 298.257223563, AUTHORITY["EPSG","7030"]], AUTHORITY["EPSG","6326"]], PRIMEM["Greenwich", 0.0, AUTHORITY["EPSG","8901"]], UNIT["degree", 0.017453292519943295], AXIS["Geodetic longitude", EAST], AXIS["Geodetic latitude", NORTH], AUTHORITY["EPSG","4326"]], PROJECTION["Transverse_Mercator", AUTHORITY["EPSG","9807"]], PARAMETER["central_meridian", 9.0], PARAMETER["latitude_of_origin", 0.0], PARAMETER["scale_factor", 0.9996], PARAMETER["false_easting", 500000.0], PARAMETER["false_northing", 0.0], UNIT["m", 1.0], AXIS["Easting", EAST], AXIS["Northing", NORTH], AUTHORITY["EPSG","32632"]]'},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [5141285.0, 5162205.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N", GEOGCS["WGS 84", DATUM["World Geodetic System 1984", SPHEROID["WGS 84", 6378137.0, 298.257223563, AUTHORITY["EPSG","7030"]], AUTHORITY["EPSG","6326"]], PRIMEM["Greenwich", 0.0, AUTHORITY["EPSG","8901"]], UNIT["degree", 0.017453292519943295], AXIS["Geodetic longitude", EAST], AXIS["Geodetic latitude", NORTH], AUTHORITY["EPSG","4326"]], PROJECTION["Transverse_Mercator", AUTHORITY["EPSG","9807"]], PARAMETER["central_meridian", 9.0], PARAMETER["latitude_of_origin", 0.0], PARAMETER["scale_factor", 0.9996], PARAMETER["false_easting", 500000.0], PARAMETER["false_northing", 0.0], UNIT["m", 1.0], AXIS["Easting", EAST], AXIS["Northing", NORTH], AUTHORITY["EPSG","32632"]]'},
#    'bands': {'type': 'bands', 'values': ['VH', 'VV']}}},
#  {'stac_version': '1.0.0-rc.2',
#   'type': 'Collection',
#   'id': 'openeo-localprocessing-data/sample_geotiff/S2_L2A_sample.tif',
#   'title': 'openeo-localprocessing-data/sample_geotiff/S2_L2A_sample.tif',
#   'description': '',
#   'license': '',
#   'providers': [{'name': '', 'roles': ['producer'], 'url': ''}],
#   'links': '',
#   'extent': {'spatial': {'bbox': [[11.279049925697631,
#       46.46209368370743,
#       11.403371964733001,
#       46.52290723269475]]}},
#   'cube:dimensions': {'x': {'type': 'spatial',
#     'axis': 'x',
#     'extent': [674995.0, 684335.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",9],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32632"]]'},
#    'y': {'type': 'spatial',
#     'axis': 'y',
#     'extent': [5147915.0, 5154955.0],
#     'reference_system': 'PROJCS["WGS 84 / UTM zone 32N",GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0,AUTHORITY["EPSG","8901"]],UNIT["degree",0.0174532925199433,AUTHORITY["EPSG","9122"]],AUTHORITY["EPSG","4326"]],PROJECTION["Transverse_Mercator"],PARAMETER["latitude_of_origin",0],PARAMETER["central_meridian",9],PARAMETER["scale_factor",0.9996],PARAMETER["false_easting",500000],PARAMETER["false_northing",0],UNIT["metre",1,AUTHORITY["EPSG","9001"]],AXIS["Easting",EAST],AXIS["Northing",NORTH],AUTHORITY["EPSG","32632"]]'},
#    'bands': {'type': 'bands', 'values': ['B04', 'B03', 'B02', 'B08', 'SCL']}}}]

# %% [markdown]
# ## Example 1: Create color composites based on Sentinel-2 data

# %% [markdown]
# The first step, as usual in an openEO pipeline, is `load_collection`. In this case, the collection id is the same as the file path we want to use:

# %%
cube = local_conn.load_collection('openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc').filter_bands(['B04','B03','B02'])

# %% [markdown]
# We would like to create a color composite based on multiple acquisitions over time.
#
# For doing so, we will use the `reduce_dimension` process, which can reduce a dimension given a reducer process.
#
# In this case the dimension is the temporal (`t`) and the reducer is `mean`, to get a temporal average.

# %%
cube_avg = cube.reduce_dimension(dimension='t',reducer='mean')

# %% [markdown]
# Since we would like to visualize the result as an image, we scale it to values between 0 and 255.

# %%
cube_scaled = cube_avg.linear_scale_range(0,2000,0,255)

# %% [markdown]
# We can now visualize the openEO process graph that we just created:

# %%
cube_scaled
# Out:
#     <script>
#     if (!window.customElements || !window.customElements.get('openeo-model-builder')) {
#         var el = document.createElement('script');
#         el.src = "https://cdn.jsdelivr.net/npm/@openeo/vue-components@2/assets/openeo.min.js";
#         document.head.appendChild(el);
#
#         var font = document.createElement('font');
#         font.as = "font";
#         font.type = "font/woff2";
#         font.crossOrigin = true;
#         font.href = "https://use.fontawesome.com/releases/v5.13.0/webfonts/fa-solid-900.woff2"
#         document.head.appendChild(font);
#     }
#     </script>
#     <openeo-model-builder>
#         <script type="application/json">{"id": "209999bd35bb40fca98c50abb650d041", "explicit-zoom": true, "height": "400px", "value": {"process_graph": {"loadcollection1": {"process_id": "load_collection", "arguments": {"id": "openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc", "spatial_extent": null, "temporal_extent": null}}, "filterbands1": {"process_id": "filter_bands", "arguments": {"bands": ["B04", "B03", "B02"], "data": {"from_node": "loadcollection1"}}}, "reducedimension1": {"process_id": "reduce_dimension", "arguments": {"data": {"from_node": "filterbands1"}, "dimension": "t", "reducer": {"process_graph": {"mean1": {"process_id": "mean", "arguments": {"data": {"from_parameter": "data"}}, "result": true}}}}}, "apply1": {"process_id": "apply", "arguments": {"data": {"from_node": "reducedimension1"}, "process": {"process_graph": {"linearscalerange1": {"process_id": "linear_scale_range", "arguments": {"inputMax": 2000, "inputMin": 0, "outputMax": 255, "outputMin": 0, "x": {"from_parameter": "x"}}, "result": true}}}}, "result": true}}}}</script>
#     </openeo-model-builder>

# %% [markdown]
# By calling `.execute()`, the process graph will be locally executed and the result will be returned as an Xarray object:

# %%
result = cube_scaled.execute()
result
# Out:
# Deserialised process graph into nested structure
# Running process load_local_collection
# kwargs: {'id': <class 'str'>, 'spatial_extent': <class 'NoneType'>, 'temporal_extent': <class 'NoneType'>}
# --------------------------------------------------------------------------------
# Running process filter_bands
# kwargs: {'bands': <class 'list'>, 'data': <class 'xarray.core.dataarray.DataArray'>}
# --------------------------------------------------------------------------------
# Running process reduce_dimension
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'dimension': <class 'str'>, 'reducer': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process mean
# kwargs: {'data': <class 'dask.array.core.Array'>, 'axis': <class 'int'>}
# --------------------------------------------------------------------------------
# Running process apply
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'process': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process linear_scale_range
# kwargs: {'inputMax': <class 'float'>, 'inputMin': <class 'float'>, 'outputMax': <class 'float'>, 'outputMin': <class 'float'>, 'x': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Walking node root-d4a3bcdf-512d-4b0a-aa78-223a9dd82469
# Walking node linearscalerange1-e6eab084-34ae-4fd0-8acc-bbaf12ef95bc
# Walking node reducedimension1-d4a3bcdf-512d-4b0a-aa78-223a9dd82469
# Walking node mean1-1c7b8c1a-dbe4-4cdf-9804-48bcadb8921a
# Walking node filterbands1-d4a3bcdf-512d-4b0a-aa78-223a9dd82469
# Walking node loadcollection1-d4a3bcdf-512d-4b0a-aa78-223a9dd82469
# <xarray.DataArray (bands: 3, y: 705, x: 935)>
# dask.array<add, shape=(3, 705, 935), dtype=float32, chunksize=(1, 705, 935), chunktype=numpy.ndarray>
# Coordinates:
#   * x            (x) float64 6.75e+05 6.75e+05 6.75e+05 ... 6.843e+05 6.843e+05
#   * y            (y) float64 5.155e+06 5.155e+06 ... 5.148e+06 5.148e+06
#     crs          |S1 ...
#   * bands        (bands) object 'B04' 'B03' 'B02'
#     spatial_ref  int64 0

# %% [markdown]
# Now that we have the result, we can plot the color composites:

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,1,figsize=(7.5,5))
result.plot.imshow(ax=ax,cmap='brg',vmin=0,vmax=255)
ax.set_title('Mean RGB composite - June 2022 - Bolzano, Italy - Sentinel-2')
plt.show()
# Out:
# /home/mclaus@eurac.edu/anaconda3/envs/eurac_openeo3/lib/python3.10/site-packages/matplotlib/cm.py:478: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %% [markdown]
# We immediately notice that something is wrong. Probably some days where cloudy! Therefore, the average image is cloudy as well.
#
# It is possible can solve this issue with two different approaches:
# 1. Trying to use a different reducer. We will try to use `median` instead of `mean`.
# 2. By applying a cloud mask, based on the Sentinel-2 SCL (Scene Classification Layer) band. (Not possible yet locally, some processes missing)

# %% [markdown]
# Let's try the first approach, using `median` instead of `mean`.

# %%
cube = local_conn.load_collection('openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc').filter_bands(['B04','B03','B02'])
cube_med = cube.reduce_dimension(dimension='t',reducer='median')
cube_scaled = cube_med.linear_scale_range(0,2000,0,255)
result_median = cube_scaled.execute()
# Out:
# Deserialised process graph into nested structure
# Running process load_local_collection
# kwargs: {'id': <class 'str'>, 'spatial_extent': <class 'NoneType'>, 'temporal_extent': <class 'NoneType'>}
# --------------------------------------------------------------------------------
# Running process filter_bands
# kwargs: {'bands': <class 'list'>, 'data': <class 'xarray.core.dataarray.DataArray'>}
# --------------------------------------------------------------------------------
# Running process reduce_dimension
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'dimension': <class 'str'>, 'reducer': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process median
# kwargs: {'data': <class 'dask.array.core.Array'>, 'axis': <class 'int'>}
# --------------------------------------------------------------------------------
# Running process apply
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'process': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process linear_scale_range
# kwargs: {'inputMax': <class 'float'>, 'inputMin': <class 'float'>, 'outputMax': <class 'float'>, 'outputMin': <class 'float'>, 'x': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Walking node root-a2e172ee-89c9-4d70-bdf2-95faf8fc9f38
# Walking node linearscalerange1-501c9cee-4949-4387-a3be-b55427306aea
# Walking node reducedimension1-a2e172ee-89c9-4d70-bdf2-95faf8fc9f38
# Walking node median1-4cdcefd5-bf0b-4b8e-85a7-fd4a789f278d
# Walking node filterbands1-a2e172ee-89c9-4d70-bdf2-95faf8fc9f38
# Walking node loadcollection1-a2e172ee-89c9-4d70-bdf2-95faf8fc9f38

# %% [markdown]
# We can now compare the results:

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,2,figsize=(15,5))
result.plot.imshow(ax=ax[0],cmap='brg',vmin=0,vmax=255)
ax[0].set_title('Mean RGB composite - June 2022 - Bolzano, Italy - Sentinel-2')
result_median.plot.imshow(ax=ax[1],cmap='brg',vmin=0,vmax=255)
ax[1].set_title('Median RGB composite - June 2022 - Bolzano, Italy - Sentinel-2')
plt.show()
# Out:
# /home/mclaus@eurac.edu/anaconda3/envs/eurac_openeo3/lib/python3.10/site-packages/matplotlib/cm.py:478: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %% [markdown]
# We could now try to more advanced method, based on the SCL layer:

# %%
cube = local_conn.load_collection('openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc')

# %% [markdown]
# We now want to mask out the SCL class 9 (CLOUD_HIGH_PROBABILITY):

# %%
scl = cube.band('SCL')
cloud_mask_high =  scl != 9
cloud_mask_medium =  scl != 8
cloud_mask = (cloud_mask_high + cloud_mask_medium) == 2

# %% [markdown]
# We can now apply the cloud mask to the input data:

# %%
cube_masked = cube.filter_bands(['B04','B03','B02']).merge_cubes(cloud_mask,overlap_resolver='multiply')

# %% [markdown]
# Check if the cloud mask is applied correctly:

# %%
cube_masked.execute()[:,0].plot.imshow(vmin=0,vmax=2500)
# Out:
# Deserialised process graph into nested structure
# Running process load_local_collection
# kwargs: {'id': <class 'str'>, 'spatial_extent': <class 'NoneType'>, 'temporal_extent': <class 'NoneType'>}
# --------------------------------------------------------------------------------
# Running process filter_bands
# kwargs: {'bands': <class 'list'>, 'data': <class 'xarray.core.dataarray.DataArray'>}
# --------------------------------------------------------------------------------
# Running process reduce_dimension
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'dimension': <class 'str'>, 'reducer': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process array_element
# kwargs: {'data': <class 'dask.array.core.Array'>, 'index': <class 'float'>, 'axis': <class 'int'>}
# --------------------------------------------------------------------------------
# Running process neq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process neq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process add
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Running process eq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process merge_cubes
# kwargs: {'cube1': <class 'xarray.core.dataarray.DataArray'>, 'cube2': <class 'xarray.core.dataarray.DataArray'>, 'overlap_resolver': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process multiply
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Walking node root-9e0bae10-6e0f-4269-bda6-817c2312603a
# Walking node multiply1-c2f309a2-13bd-4ff1-ae3f-cfec5b2342dc
# Walking node filterbands1-9e0bae10-6e0f-4269-bda6-817c2312603a
# Walking node loadcollection1-9e0bae10-6e0f-4269-bda6-817c2312603a
# Walking node reducedimension1-9e0bae10-6e0f-4269-bda6-817c2312603a
# Walking node eq1-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node add1-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node neq1-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node arrayelement1-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node neq2-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node arrayelement1-99e1ce64-bddc-4039-af89-1bc1d71f49c6
# Walking node loadcollection1-9e0bae10-6e0f-4269-bda6-817c2312603a
# /home/mclaus@eurac.edu/anaconda3/envs/eurac_openeo3/lib/python3.10/site-packages/matplotlib/cm.py:478: RuntimeWarning: invalid value encountered in cast
#   xx = (xx * 255).astype(np.uint8)

# %% [markdown]
# And finally take the mean over time, rescale and execute:

# %%
cube_masked = cube_masked.reduce_dimension(dimension='t',reducer='median').linear_scale_range(0,2000,0,255)
cube_masked
# Out:
#     <script>
#     if (!window.customElements || !window.customElements.get('openeo-model-builder')) {
#         var el = document.createElement('script');
#         el.src = "https://cdn.jsdelivr.net/npm/@openeo/vue-components@2/assets/openeo.min.js";
#         document.head.appendChild(el);
#
#         var font = document.createElement('font');
#         font.as = "font";
#         font.type = "font/woff2";
#         font.crossOrigin = true;
#         font.href = "https://use.fontawesome.com/releases/v5.13.0/webfonts/fa-solid-900.woff2"
#         document.head.appendChild(font);
#     }
#     </script>
#     <openeo-model-builder>
#         <script type="application/json">{"id": "b2b6204587894f7aa9eeab3e3617d085", "explicit-zoom": true, "height": "400px", "value": {"process_graph": {"loadcollection1": {"process_id": "load_collection", "arguments": {"id": "openeo-localprocessing-data/sample_netcdf/S2_L2A_sample.nc", "spatial_extent": null, "temporal_extent": null}}, "filterbands1": {"process_id": "filter_bands", "arguments": {"bands": ["B04", "B03", "B02"], "data": {"from_node": "loadcollection1"}}}, "reducedimension1": {"process_id": "reduce_dimension", "arguments": {"data": {"from_node": "loadcollection1"}, "dimension": "bands", "reducer": {"process_graph": {"arrayelement1": {"process_id": "array_element", "arguments": {"data": {"from_parameter": "data"}, "index": 4}}, "neq1": {"process_id": "neq", "arguments": {"x": {"from_node": "arrayelement1"}, "y": 9}}, "neq2": {"process_id": "neq", "arguments": {"x": {"from_node": "arrayelement1"}, "y": 8}}, "add1": {"process_id": "add", "arguments": {"x": {"from_node": "neq1"}, "y": {"from_node": "neq2"}}}, "eq1": {"process_id": "eq", "arguments": {"x": {"from_node": "add1"}, "y": 2}, "result": true}}}}}, "mergecubes1": {"process_id": "merge_cubes", "arguments": {"cube1": {"from_node": "filterbands1"}, "cube2": {"from_node": "reducedimension1"}, "overlap_resolver": {"process_graph": {"multiply1": {"process_id": "multiply", "arguments": {"x": {"from_parameter": "x"}, "y": {"from_parameter": "y"}}, "result": true}}}}}, "reducedimension2": {"process_id": "reduce_dimension", "arguments": {"data": {"from_node": "mergecubes1"}, "dimension": "t", "reducer": {"process_graph": {"median1": {"process_id": "median", "arguments": {"data": {"from_parameter": "data"}}, "result": true}}}}}, "apply1": {"process_id": "apply", "arguments": {"data": {"from_node": "reducedimension2"}, "process": {"process_graph": {"linearscalerange1": {"process_id": "linear_scale_range", "arguments": {"inputMax": 2000, "inputMin": 0, "outputMax": 255, "outputMin": 0, "x": {"from_parameter": "x"}}, "result": true}}}}, "result": true}}}}</script>
#     </openeo-model-builder>

# %%
result_masked = cube_masked.execute()
# Out:
# Deserialised process graph into nested structure
# Running process load_local_collection
# kwargs: {'id': <class 'str'>, 'spatial_extent': <class 'NoneType'>, 'temporal_extent': <class 'NoneType'>}
# --------------------------------------------------------------------------------
# Running process filter_bands
# kwargs: {'bands': <class 'list'>, 'data': <class 'xarray.core.dataarray.DataArray'>}
# --------------------------------------------------------------------------------
# Running process reduce_dimension
# kwargs: {'data': <class 'xarray.core.dataarray.DataArray'>, 'dimension': <class 'str'>, 'reducer': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process array_element
# kwargs: {'data': <class 'dask.array.core.Array'>, 'index': <class 'float'>, 'axis': <class 'int'>}
# --------------------------------------------------------------------------------
# Running process neq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process neq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process add
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Running process eq
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'float'>}
# --------------------------------------------------------------------------------
# Running process merge_cubes
# kwargs: {'cube1': <class 'xarray.core.dataarray.DataArray'>, 'cube2': <class 'xarray.core.dataarray.DataArray'>, 'overlap_resolver': <class 'functools.partial'>}
# --------------------------------------------------------------------------------
# Running process multiply
# kwargs: {'x': <class 'dask.array.core.Array'>, 'y': <class 'dask.array.core.Array'>}
# --------------------------------------------------------------------------------
# Walking node root-028cca22-74d8-48f3-acae-54901017b3e2
# Walking node multiply1-5b85ba89-4ca6-411e-9b20-f5d62bb6fde1
# Walking node filterbands1-028cca22-74d8-48f3-acae-54901017b3e2
# Walking node loadcollection1-028cca22-74d8-48f3-acae-54901017b3e2
# Walking node reducedimension1-028cca22-74d8-48f3-acae-54901017b3e2
# Walking node eq1-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node add1-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node neq1-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node arrayelement1-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node neq2-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node arrayelement1-3e9e96e4-7c97-4c46-b6fe-a633d145554c
# Walking node loadcollection1-028cca22-74d8-48f3-acae-54901017b3e2

# %% [markdown]
# Finally visualize the result and compare with the median version with no cloud filter:

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots(1,2,figsize=(15,5))
result_median.plot.imshow(ax=ax[0],cmap='brg',vmin=0,vmax=255)
ax[0].set_title('Median RGB composite - June 2022 - Bolzano, Italy - Sentinel-2')
result_masked.plot.imshow(ax=ax[1],cmap='brg',vmin=0,vmax=255)
ax[1].set_title('Median RGB composite cloud masked - June 2022 - Bolzano, Italy - Sentinel-2')
plt.show()
